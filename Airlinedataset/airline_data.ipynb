# %%
#import libraries
import pandas as pd
import zipfile as zf 
import kaggle
import numpy as np

# %%
flights = pd.read_csv("Airline Dataset Updated - v2.csv")

# %%
#explore data
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98619 entries, 0 to 98618
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Passenger ID          98619 non-null  object
#  1   First Name            98619 non-null  object
#  2   Last Name             98619 non-null  object
#  3   Gender                98619 non-null  object
#  4   Age                   98619 non-null  int64
#  5   Nationality           98619 non-null  object
#  6   Airport Name          98619 non-null  object
#  7   Airport Country Code  98619 non-null  object
#  8   Country Name          98619 non-null  object
#  9   Airport Continent     98619 non-null  object
#  10  Continents            98619 non-null  object
#  11  Departure Date        98619 non-null  object
#  12  Arrival Airport       98619 non-null  object
#  13  Pilot Name            98619 non-null  object
#  14  Flight Status         98619 non-null  object
# ...

# %%
flights.shape
# Out:
# (98619, 15)

# %%
flights
# Out:
#       Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0           ABVWIg      Edithe     Leggis  Female   62       Japan
# 1           jkXXAX      Elwood       Catt    Male   62   Nicaragua
# 2           CdUz2g       Darby    Felgate    Male   67      Russia
# 3           BRS38V    Dominica       Pyle  Female   71       China
# 4           9kvTLo         Bay    Pencost    Male   21       China
# ...            ...         ...        ...     ...  ...         ...
# 98614       hnGQ62      Gareth    Mugford    Male   85       China
# 98615       2omEzh       Kasey   Benedict  Female   19      Russia
# 98616       VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 98617       E47NtS       Gayle  Lievesley  Female   34       China
# 98618       8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 0                 Coldfoot Airport                   US       United States
# ...

# %%
#checking unique values
flights.Gender.value_counts()
# Out:
# Gender
# Male      49598
# Female    49021
# Name: count, dtype: int64

# %%
flights.Nationality.value_counts()
# Out:
# Nationality
# China                     18317
# Indonesia                 10559
# Russia                     5693
# Philippines                5239
# Brazil                     3791
#                           ...
# Romania                       2
# British Virgin Islands        2
# Jersey                        1
# Norfolk Island                1
# Sint Maarten                  1
# Name: count, Length: 240, dtype: int64

# %%
flights['Airport Name'].value_counts()
# Out:
# Airport Name
# San Pedro Airport             43
# Santa Maria Airport           38
# Böblingen Flugfeld            36
# Santa Ana Airport             35
# San Fernando Airport          31
#                               ..
# Balıkesir Merkez Airport       2
# Arkalyk North Airport          2
# Juba International Airport     2
# Falcon State Airport           1
# Hiroshima Airport              1
# Name: count, Length: 9062, dtype: int64

# %%
#cleaining up missing values
flights['Arrival Airport']= flights['Arrival Airport'].replace('0',np.nan)
flights['Arrival Airport'].value_counts()
# Out:
# Arrival Airport
# JNB    37
# PHM    36
# MPT    32
# YTY    27
# PCO    27
#        ..
# CXM     2
# IPI     2
# BQU     2
# FAL     1
# HIJ     1
# Name: count, Length: 9023, dtype: int64

# %%
flights['Flight Status'].value_counts()
# Out:
# Flight Status
# Cancelled    32942
# On Time      32846
# Delayed      32831
# Name: count, dtype: int64

# %%
print(flights.columns)
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
print(flights['Gender'].unique())
# Out:
# ['Female' 'Male']

# %%
#mapping values of gender and flight status
gender_mapping = {'Male': 0, 'Female': 1}
flights['Gender'] = flights['Gender'].map(gender_mapping)

status_mapping = {'Cancelled': 0, 'On Time': 1, 'Delayed': 2}
flights['Flight Status'] = flights['Flight Status'].map(status_mapping)

# %%
flights.head()
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis       1   62       Japan
# 1       jkXXAX     Elwood      Catt       0   62   Nicaragua
# 2       CdUz2g      Darby   Felgate       0   67      Russia
# 3       BRS38V   Dominica      Pyle       1   71       China
# 4       9kvTLo        Bay   Pencost       0   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# ...

# %%
# writing the final dataframe to an excel file
flights.to_excel('Airline Dataset Final - v3.xlsx', sheet_name='Data')
